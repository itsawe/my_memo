# %% [markdown]
# # REGEX MEMO
#
# #### Character classes
# - .	        any character except newline
# - \w\d\s	word, digit, whitespace
# - \W\D\S	not word, digit, whitespace
# - [abc]	    any of a, b, or c
# - [^abc]	not a, b, or c
# - [a-g]	    character between a & g
#
# #### Anchors
# - ^abc$	    start / end of the string
# - \b\B	    word, not-word boundary
#
# ##### Escaped characters
# - \.\*\\	escaped special characters
# - \t\n\r	tab, linefeed, carriage return
#
# #### Groups & Lookaround
# - (abc)	    capture group
# - \1	    backreference to group #1
# - (?:abc)	non-capturing group
# - (?=abc)	positive lookahead
# - (?!abc)	negative lookahead
#
# #### Quantifiers & Alternation
# - a*a+a?	0 or more, 1 or more, 0 or 1
# - a{5}a{2,}	exactly five, two or more
# - a{1,3}	between one & three
# - a+?a{2,}?	match as few as possible
# - ab|cd	    match ab or cd
#
# For testing Regex, refer to this site: [regexr.com](https://regexr.com/)
#
# Below is some refresher for using regex

# %%
import pandas as pd
import numpy as np

hn = pd.read_csv('hacker_news.csv')

# %%
hn
# Out:
#              id                                              title  \
# 0      12224879                          Interactive Dynamic Video
# 1      11964716  Florida DJs May Face Felony for April Fools' W...
# 2      11919867       Technology ventures: From Idea to Enterprise
# 3      10301696  Note by Note: The Making of Steinway L1037 (2007)
# 4      10482257  Title II kills investment? Comcast and other I...
# 5      10557283                     Nuts and Bolts Business Advice
# 6      12296411        Ask HN: How to improve my personal website?
# 7      11337617  Shims, Jigs and Other Woodworking Concepts to ...
# 8      10379326                             That self-appendectomy
# 9      11370829  Crate raises $4M seed round for its next-gen S...
# 10     11665197  Advertising Cannot Maintain the Internet. Here...
# 11     11981466                                     Coding Is Over
# 12     10627194  Show HN: Wio Link  ESP8266 Based Web of Things...
# 13     11587596             Custom Deleters for C++ Smart Pointers
# 14     12335860         How often to update third party libraries?
# 15     11403750                   Review my AI based marketing bot
# 16     10610020  Ask HN: Am I the only one outraged by Twitter ...
# 17     10837634     Ten years later, did Boston's Big Dig deliver?
# 18     12121216          Valid.ly  Never send another OOPS message
# 19     11079821                APOD: LIGO detects gravity waves...
# 20     11007942  Typeplate: a typographic starter kit encouragi...
# 21     11610310  Ask HN: Aby recent changes to CSS that broke m...
# 22     10712549  Streamroot makes video streaming cheaper thank...
# 23     10978069  VMware Confirms Layoffs as It Prepares for Del...
# 24     12023949  Firmware exploit can defeat new Windows securi...
# 25     10739227           The Sad State of Personal Knowledgebases
# 26     11181546                           US Robotics Network Taps
# 27     11161191                Fundraising Advice for YC Companies
# 28     10760605  PSA: Intel WICS broken for years with official...
# 29     12210105    Ask HN: Looking for Employee #3 How do I do it?
# ...         ...                                                ...
# 20069  12149183  Show HN: Parse recipe ingredients using JavaSc...
# 20070  11473902  Engineering PhD student who died last year wil...
# 20071  10942147  Apples Amazing New Music App Hits All the Righ...
# 20072  11485277  Airbnb acquires team of Bitcoin and blockchain...
# 20073  10469896                                   Is Tesla Doomed?
# 20074  12151906  An Experiment with GitHub Pages, Jekyll and Tr...
# 20075  12532304  Tips from a Pro: An Introduction to Microscopi...
# 20076  10741606  Comcast CEO to angry customers: Its not me, it...
# 20077  12065681  The Renewed Case for the Reduced Instruction S...
# 20078  12317616  U.S. Judge Rejects Ubers Proposed $100M Settle...
# 20079  11294026                        English Syntax Highlighting
# 20080  11925814                 The Geek Behind Google's Map Quest
# 20081  10638339               Usenet, what have you become? (2012)
# 20082  11138742  Colma, Calif., Is a Town of 2.2 Square Miles, ...
# 20083  12490497  The bizarre world of Bitcoin mining finds a ne...
# 20084  11194636  Microservice on-top of distributed filesystem ...
# 20085  10526324  Satoshi Nakamoto officially nominated for the ...
# 20086  11452432    Debian XScreenSaver package maintainer responds
# 20087  10788826        TSA Sued Over New Policy to Refuse Opt-Outs
# 20088  10499089  I have $10,000 dollars in my bank account. Am ...
# 20089  11433605  Users Really Do Plug in USB Drives They Find [...
# 20090  10588305  Visual Studio now available in cloud subscript...
# 20091  11870578  Thought leader gives talk that will inspire yo...
# 20092  10404949            On Botnets and Streaming Music Services
# 20093  10524489             Two new steps toward quantum computing
# 20094  12379592  How Purism Avoids Intels Active Management Tec...
# 20095  10339284          YC Application Translated and Broken Down
# 20096  10824382  Microkernels are slow and Elvis didn't do no d...
# 20097  10739875                      How Product Hunt really works
# 20098  11680777  RoboBrowser: Your friendly neighborhood web sc...
#
#                                                      url  num_points  \
# 0                http://www.interactivedynamicvideo.com/         386
# 1      http://www.thewire.com/entertainment/2013/04/f...           2
# 2      https://www.amazon.com/Technology-Ventures-Ent...           3
# 3      http://www.nytimes.com/2007/11/07/movies/07ste...           8
# 4      http://arstechnica.com/business/2015/10/comcas...          53
# 5                                                    NaN           3
# 6                                                    NaN           2
# 7      http://firstround.com/review/shims-jigs-and-ot...          34
# 8      http://www.southpolestation.com/trivia/igy1/ap...          91
# 9      http://techcrunch.com/2016/03/15/crate-raises-...           3
# 10     http://evonomics.com/advertising-cannot-mainta...           2
# 11     https://medium.com/@loorinm/coding-is-over-6d6...          18
# 12                                  https://iot.seeed.cc          26
# 13     http://www.bfilipek.com/2016/04/custom-deleter...          59
# 14                                                   NaN           7
# 15           http://beta.crowdfireapp.com/?beta=agnipath           1
# 16                                                   NaN          28
# 17     https://www.bostonglobe.com/magazine/2015/12/2...         109
# 18                                  https://www.valid.ly           1
# 19               http://apod.nasa.gov/apod/astropix.html           1
# 20                                 http://typeplate.com/          68
# 21                                                   NaN           1
# 22     http://techcrunch.com/2015/12/10/streamroot-ma...          11
# 23     http://techcrunch.com/2016/01/26/vmware-confir...         170
# 24     http://www.pcworld.com/article/3091104/firmwar...          15
# 25     http://marcusvorwaller.com/blog/2015/12/14/per...         115
# 26       http://www.usr.com/en/products/networking-taps/           1
# 27     https://blog.ycombinator.com/fundraising-advic...         234
# 28            https://communities.intel.com/thread/96038           4
# 29                                                   NaN           1
# ...                                                  ...         ...
# 20069       https://github.com/herkyl/ingredients-parser           6
# 20070  http://host.madison.com/wsj/news/local/uw-engi...         145
# 20071  https://www.yahoo.com/tech/apple-s-amazing-new...           4
# 20072  http://qz.com/657246/airbnb-just-acquired-a-te...          13
# 20073  http://www.roadandtrack.com/car-culture/a26859...           3
# 20074  http://darek.dk/2016/05/29/an-experiment-with-...           3
# 20075  http://www.popphoto.com/tips-pro-microscopic-p...          51
# 20076  http://www.vox.com/business-and-finance/2015/1...           7
# 20077  http://www.eecs.berkeley.edu/Pubs/TechRpts/201...          69
# 20078  http://www.wsj.com/articles/u-s-judge-rejects-...          54
# 20079  http://evanhahn.github.io/English-text-highlig...         248
# 20080  http://www.fastcompany.com/3060811/most-creati...           1
# 20081  http://www.90percentofeverything.com/2012/08/2...          63
# 20082  http://www.nytimes.com/2006/12/09/us/09cemeter...          56
# 20083  https://www.washingtonpost.com/world/asia_paci...           2
# 20084  https://medium.com/@lorenzogotuned/applying-so...           3
# 20085  http://www.huffingtonpost.com/bhagwan-chowdry/...          47
# 20086  https://bugs.debian.org/cgi-bin/bugreport.cgi?...          38
# 20087  http://professional-troublemaker.com/2015/12/2...         112
# 20088  https://medium.com/@sktgthill/i-have-10-000-do...           1
# 20089                  https://zakird.com/papers/usb.pdf           3
# 20090  https://www.visualstudio.com/products/how-to-b...         113
# 20091        https://www.youtube.com/watch?v=_ZBKX-6Gz6A           4
# 20092  http://motherboard.vice.com/read/i-built-a-bot...         120
# 20093      http://phys.org/news/2015-11-big-quantum.html          14
# 20094  https://puri.sm/philosophy/how-purism-avoids-i...          10
# 20095  https://medium.com/@zreitano/the-yc-applicatio...           4
# 20096  http://blog.darknedgy.net/technology/2016/01/0...         169
# 20097  https://medium.com/@benjiwheeler/how-product-h...         695
# 20098              https://github.com/jmcarp/robobrowser         182
#
#        num_comments          author        created_at
# 0                52        ne0phyte    8/4/2016 11:52
# 1                 1        vezycash   6/23/2016 22:20
# 2                 1         hswarna    6/17/2016 0:01
# 3                 2      walterbell    9/30/2015 4:12
# 4                22          Deinos   10/31/2015 9:48
# 5                 4        shomberj   11/13/2015 0:45
# 6                 6    ahmedbaracat    8/16/2016 9:55
# 7                 7              zt   3/22/2016 16:18
# 8                10        jimsojim   10/13/2015 9:30
# 9                 1        hitekker   3/27/2016 18:08
# 10                1     dredmorbius    5/10/2016 4:46
# 11               14      prostoalex   6/26/2016 16:36
# 12               22         kfihihc  11/25/2015 14:03
# 13               18           ingve   4/28/2016 10:01
# 14                5      rabid_oxen   8/22/2016 12:37
# 15                2   abhishekmaddy     4/1/2016 9:45
# 16               29            tkfx  11/22/2015 13:43
# 17              116        jseliger    1/4/2016 18:58
# 18                1         validly   7/19/2016 12:05
# 19                2      AliCollins   2/11/2016 12:57
# 20               13           Tomte   1/31/2016 20:38
# 21                1       polskibus    5/2/2016 10:14
# 22                2            Rodi  12/10/2015 18:58
# 23              112  walterclifford    1/27/2016 3:47
# 24                4      walterbell    7/2/2016 22:08
# 25              106       zzzmarcus  12/15/2015 17:56
# 26                2             mkj   2/26/2016 14:35
# 27              100         cryptoz   2/23/2016 18:41
# 28                1   KyleSanderson  12/18/2015 20:02
# 29                3          sph130    8/2/2016 14:20
# ...             ...             ...               ...
# 20069             2  zongitsrinzler   7/23/2016 11:35
# 20070            19   DarkContinent   4/11/2016 18:23
# 20071             1        snake117   1/20/2016 23:09
# 20072             1       onthedole    4/13/2016 2:29
# 20073             3          tomcam   10/29/2015 9:10
# 20074             1         darekdk    7/24/2016 2:16
# 20075             4           Tomte   9/19/2016 15:45
# 20076             1        praneshp   12/16/2015 0:47
# 20077            31           ingve   7/10/2016 14:28
# 20078            56          Kaedon    8/19/2016 2:30
# 20079           105           azdle    3/16/2016 0:06
# 20080             2     chickenbane   6/17/2016 22:00
# 20081            57       pmoriarty  11/27/2015 18:42
# 20082            37        apsec112    2/20/2016 4:00
# 20083             1        e15ctr0n   9/13/2016 17:36
# 20084             1           tuned   2/29/2016 10:26
# 20085             6          rmason   11/7/2015 21:33
# 20086            40   ashitlerferad     4/8/2016 3:41
# 20087            75  tsaoutourpants  12/24/2015 17:19
# 20088             1       thileepan   11/3/2015 12:29
# 20089             2         dadrian    4/5/2016 19:31
# 20090            41    mynameisvlad  11/18/2015 15:45
# 20091             1       Analemma_    6/9/2016 16:49
# 20092            70     6stringmerc  10/17/2015 16:35
# 20093             2          djmylt   11/7/2015 11:27
# 20094             6   AdmiralAsshat    8/29/2016 2:22
# 20095             1        zreitano   10/6/2015 14:57
# 20096           132     vezzy-fnord     1/2/2016 0:49
# 20097           222           brw12  12/15/2015 19:32
# 20098            58       pmoriarty    5/12/2016 1:43
#
# [20099 rows x 7 columns]

# %%
import re

# %%
python_mentions = 0
pattern = '[pP]ython'
titles = hn['title']

for title in titles:
    if re.search(pattern, title):
        python_mentions += 1

python_mentions
# Out:
# 160

# %%
v_python_mentions = titles.str.contains(pattern).sum()

v_python_mentions
# Out:
# 160

# %%
ruby_titles = titles[titles.str.contains('[Rr]uby')]

ruby_titles.head()
# Out:
# 190                    Ruby on Google AppEngine Goes Beta
# 484          Related: Pure Ruby Relational Algebra Engine
# 1388    Show HN: HTTPalooza  Ruby's greatest HTTP clie...
# 1949    Rewriting a Ruby C Extension in Rust: How a Na...
# 2022    Show HN: CrashBreak  Reproduce exceptions as f...
# Name: title, dtype: object

# %%
email_bool = titles.str.contains('e-?mail')

# %%
email_counts = email_bool.sum()

email_counts
# Out:
# 86

# %%
email_titles = titles[email_bool]

email_titles
# Out:
# 119      Show HN: Send an email from your shell to your...
# 313          Disposable emails for safe spam free shopping
# 1361     Ask HN: Doing cold emails? helps us prove this...
# 1750     Protect yourself from spam, bots and phishing ...
# 2421                    Ashley Madison hack treating email
# 2685          Ask HN: Weather forecast in your email daily
# 3379            Ask HN: How do we solve the email problem?
# 3865     What Mailchimp does to make sure emails get de...
# 3889     Show HN: Do you know what emails your competit...
# 3921      Im killing most of my email capture. Here's why.
# 4219              Ask HN: One email, multiple team members
# 4318     How to get your email newsletter out of promot...
# 4322     SecureMyEmail  email client that automatically...
# 4577              Show HN: Gaggle Mail  Simple group email
# 4837     Ask HN: How do you manage per-service emails w...
# 4901     Show HN: GPG-Mailer  send GPG-encrypted emails...
# 5314     Ask HN: Has anybody built Tinder/Imgur style m...
# 5782     Tutonota: An end-to-end encrypted email client...
# 5961     Ask HN: What are the most clever email collect...
# 6018     Inky 3  Encrypted emails using ANY email provider
# 6101     Leaked Apple emails reveal employees' complain...
# 6254     Ask HN: Why is it still so hard to host your o...
# 6933     How do I find out who has sent me the most ema...
# 7106     I have 23 keybase.io invites emails in the com...
# 7124     GitHub exposes everyone's email address in GIT...
# 7366     Code to transform Hillary's emails from raw PD...
# 7514                                Knowmail  AI for email
# 7751     Snowden and WikiLeaks clash over leaked Democr...
# 7909       Ask HN: Why the hell can't you return my email?
# 8732     Show HN: Mailroof.com  Map-based CRM in your e...
#                                ...
# 13016                          Y Combinator emails are out
# 13157    Ray Tomlinson, creator of e-mail, has passed away
# 13347    PixelBlock  Block email open tracking in Gmail...
# 13411          Si.gnatu.re: HTML email signature generator
# 13518    Magic  Completes signup forms automatically, w...
# 13855    Ask HN: Any one getting other people's emails ...
# 14164    Ask HN: Is there still demand for animated ema...
# 14344     Slack beats email, but still needs to get better
# 14508           Find Twitter user by email or phone number
# 14526    Show HN: Mailer  our in-house tool for sending...
# 14881    US Intelligence directors personal e-mail, pho...
# 14935    Ask HN: Anyone else *still* having no email de...
# 14945            How to get benefits from email marketing?
# 15216    Beware: Nylas cloud email retains all emails a...
# 15281    Show HN: Double Your Network (a free, 10-day e...
# 15300    A Humble email alternative app with a stop switch
# 15408    Google has most of my email because it has all...
# 15489    Hillary's IT guy asking Reddit how to cover up...
# 15682    QUESTION: Why does no email have native video?...
# 16152    Avoid committing to GitHub with your company e...
# 16508    State Dept.: Clinton IT aide's email archive i...
# 16794    Turkey blocks access to WikiLeaks after email-...
# 17004    TRACEMAIL: Visualize the path of your emails, ...
# 17415    Microsoft failed to warn victims of Chinese em...
# 17924                 How Clintons email scandal took root
# 18098    House panel looking into Reddit post about Cli...
# 18583    Mailgen  Generates clean, responsive HTML for ...
# 18847    Show HN: Crisp iOS keyboard for email and text...
# 19303    Ask HN: Why big email providers don't sign the...
# 19446    Tell HN: Secure email provider Riseup will run...
# Name: title, Length: 86, dtype: object

# %%
tag_pattern = '\[\w+\]'

tag_titles = titles[titles.str.contains(tag_pattern)]

tag_count = tag_titles.shape[0]

tag_count
# Out:
# 444

# %%
extract_pattern = r'\[(\w+)\]'

# parameter : expand=False -> to produce result as pandas series, so we can use value_counts immediately
tags     = titles.str.extract(extract_pattern,expand=False) 
tag_freq = tags.value_counts().sort_values(ascending=False)

tag_freq
# Out:
# pdf            276
# video          111
# 2015             3
# audio            3
# beta             2
# 2014             2
# slides           2
# SPA              1
# Australian       1
# Beta             1
# blank            1
# Ubuntu           1
# React            1
# Infograph        1
# Skinnywhale      1
# Python           1
# song             1
# much             1
# JavaScript       1
# HBR              1
# NSFW             1
# ask              1
# 2008             1
# satire           1
# videos           1
# Live             1
# repost           1
# Excerpt          1
# German           1
# 1996             1
# crash            1
# gif              1
# ANNOUNCE         1
# Benchmark        1
# png              1
# CSS              1
# Videos           1
# map              1
# Challenge        1
# transcript       1
# survey           1
# Petition         1
# 5                1
# viz              1
# GOST             1
# coffee           1
# Map              1
# USA              1
# detainee         1
# updated          1
# comic            1
# SpaceX           1
# Name: title, dtype: int64

# %%
def first_10_matches(pattern):
    results = titles[titles.str.contains(pattern)]
    return results.heads(10)

# %%
java_pattern = r"\b[jJ]ava\b"

java_titles = titles[titles.str.contains(java_pattern)]

java_titles.shape[0]
# Out:
# 54

# %%
beginning_count = titles[titles.str.contains(r"^\[\w+\]")].shape[0]
ending_count = titles[titles.str.contains(r"\[\w+\]$")].shape[0]

print("beginning count: ", beginning_count," ending count: " , ending_count)
# Out:
# beginning count:  15  ending count:  417

# %%
email_tests = pd.Series(['email', 'Email', 'e Mail', 'e mail', 'E-mail',
              'e-mail', 'eMail', 'E-Mail', 'EMAIL'])

# %%
#possible patterns = r"e[\-\s]?mail"  || r'e-?|\s?mail'
email_mentions = email_tests.str.contains(r'e[\-\s]?mail', flags= re.I).sum()

email_mentions
# Out:
# 9

# %%
email_pattern = r"e[\-\s]?mail"

email_mentions = titles.str.contains(email_pattern,flags = re.I).sum()

print(email_mentions)

email_titlez = titles[titles.str.contains(email_pattern,flags = re.I)]

email_titlez
# Out:
# 151
# 119      Show HN: Send an email from your shell to your...
# 161      Computer Specialist Who Deleted Clinton Emails...
# 174                                        Email Apps Suck
# 261      Emails Show Unqualified Clinton Foundation Don...
# 313          Disposable emails for safe spam free shopping
# 332                           Inky: Secure Email Made Easy
# 450      Mailtrain (the open source Mailchimp clone) is...
# 1361     Ask HN: Doing cold emails? helps us prove this...
# 1750     Protect yourself from spam, bots and phishing ...
# 1774     From Email Introductions to Addressing Diversi...
# 1900     Police Emails About Ahmed Mohamed: 'This Is Wh...
# 1956                   Email newsletters are the new zines
# 2018     Emails from a CEO Who Just Has a Few Changes t...
# 2421                    Ashley Madison hack treating email
# 2685          Ask HN: Weather forecast in your email daily
# 3181     Validating Email Addresses with a Regex? Do Yo...
# 3379            Ask HN: How do we solve the email problem?
# 3561     Yale Students Demand Resignations from Faculty...
# 3602     Show HN: Simple Responsive HTML Email Template...
# 3820     Show HN: Weebly 4  Websites, eCommerce and Ema...
# 3865     What Mailchimp does to make sure emails get de...
# 3889     Show HN: Do you know what emails your competit...
# 3921      Im killing most of my email capture. Here's why.
# 3967     Russia Is Reportedly Set to Release Clinton's ...
# 4202     Jim Comey's Statement on the Clinton Emails: A...
# 4219              Ask HN: One email, multiple team members
# 4318     How to get your email newsletter out of promot...
# 4322     SecureMyEmail  email client that automatically...
# 4504            The fine art of literary hate mail endures
# 4577              Show HN: Gaggle Mail  Simple group email
#                                ...
# 15464                      Responsive HTML Email Templates
# 15489    Hillary's IT guy asking Reddit how to cover up...
# 15607                  Improvements to Notification Emails
# 15682    QUESTION: Why does no email have native video?...
# 15735                          The Hostile Email Landscape
# 15738                      The Dreaded Weekly Status Email
# 15846    Millions of Gmail, Hotmail and Yahoo Emails an...
# 15913                   Foiling Electronic Snoops in Email
# 16056     Another Hack: 117M LinkedIn Emails and Passwords
# 16131    Russias Amazon for Prisoners Offers Online Sho...
# 16152    Avoid committing to GitHub with your company e...
# 16508    State Dept.: Clinton IT aide's email archive i...
# 16794    Turkey blocks access to WikiLeaks after email-...
# 17004    TRACEMAIL: Visualize the path of your emails, ...
# 17060        This Email Subscription Will Make You Smarter
# 17214                             Why Email does not stink
# 17374              POPFile  Automatic Email Classification
# 17415    Microsoft failed to warn victims of Chinese em...
# 17440    More Encryption, More Notifications, More Emai...
# 17826    Show HN: Email PaaS Pricing (for former Mandri...
# 17924                 How Clintons email scandal took root
# 17926             Disposable, Secure, Email Built in Rails
# 18098    House panel looking into Reddit post about Cli...
# 18583    Mailgen  Generates clean, responsive HTML for ...
# 18847    Show HN: Crisp iOS keyboard for email and text...
# 19303    Ask HN: Why big email providers don't sign the...
# 19395    I used HTML Email when applying for jobs, here...
# 19446    Tell HN: Secure email provider Riseup will run...
# 19838                      Petition to Open Source Mailbox
# 19905    Gmail Will Soon Warn Users When Emails Arrive ...
# Name: title, Length: 151, dtype: object

# %%
sql_count = titles.str.contains(r'SQL',flags=re.I).sum()

sql_count
# Out:
# 108

# %%
hn_sql = hn[hn['title'].str.contains(r'\w+SQL',flags=re.I)].copy()

# %%
hn_sql['flavor'] = hn_sql['title'].str.extract(r'(\w+SQL)',flags=re.I)

hn_sql['flavor'] = hn_sql['flavor'].str.lower()

# %%
sql_pivot = hn_sql.pivot_table(index='flavor', values='num_comments', aggfunc='mean')

# %%
python_pattern = r"([Pp]ython [\d\.]+)"

py_versions = hn['title'].str.extract(python_pattern,expand=False)

py_versions_freq = dict(py_versions.value_counts())

py_versions_freq
# Out:
# {'Python 3': 10,
#  'Python 3.5': 3,
#  'Python 2': 2,
#  'Python 3.6': 2,
#  'Python 2.7': 1,
#  'Python 8': 1,
#  'Python 1.5': 1,
#  'python 2': 1,
#  'Python 4': 1,
#  'Python 3.5.0': 1}

# %%
first_ten = titles[titles.str.contains(r'\b[Cc]\b[^\+\.]')].head(10)

first_ten
# Out:
# 365                      The new C standards are worth it
# 444           Moz raises $10m Series C from Foundry Group
# 521          Fuchsia: Micro kernel written in C by Google
# 1307            Show HN: Yupp, yet another C preprocessor
# 1326                     The C standard formalized in Coq
# 1365                          GNU C Library 2.23 released
# 1429    Cysignals: signal handling (SIGINT, SIGSEGV, )...
# 1620                        SDCC  Small Device C Compiler
# 1949    Rewriting a Ruby C Extension in Rust: How a Na...
# 2195    MyHTML  HTML Parser on Pure C with POSIX Threa...
# Name: title, dtype: object

# %%
pattern = r"(?<!Series\s)\b[cC]\b(?![\+\.])"
c_mentions = titles.str.contains(pattern).sum()

# %%
pattern = r"\b(\w+)\s\1\b"

repeated_words = titles[titles.str.contains(pattern)]
repeated_words
# Out:
# d:\program files\python\lib\site-packages\ipykernel_launcher.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 3102                  Silicon Valley Has a Problem Problem
# 3176                Wire Wire: A West African Cyber Threat
# 3178                         Flexbox Cheatsheet Cheatsheet
# 4797                            The Mindset Mindset (2015)
# 7276     Valentine's Day Special: Bye Bye Tinder, Flirt...
# 10371    Mcdonalds copying cyriak  cows cows cows in th...
# 11575                                    Bang Bang Control
# 11901          Cordless Telephones: Bye Bye Privacy (1991)
# 12697          Solving the the Monty-Hall-Problem in Swift
# 15049    Bye Bye Webrtc2SIP: WebRTC with Asterisk and A...
# 15839          Intellij-Rust Rust Plugin for IntelliJ IDEA
# Name: title, dtype: object

# %%
#get email
pattern = r"e[\-\s]?mail"

email_variations = pd.Series(['email', 'Email', 'e Mail',
                        'e mail', 'E-mail', 'e-mail',
                        'eMail', 'E-Mail', 'EMAIL'])

email_uniform = email_variations.str.replace(pattern,"email",flags=re.I)

email_uniform
# Out:
# 0    email
# 1    email
# 2    email
# 3    email
# 4    email
# 5    email
# 6    email
# 7    email
# 8    email
# dtype: object

# %%
titles_clean = titles.str.replace(pattern,"email",flags=re.I)

# %%
titles_clean
# Out:
# 0                                Interactive Dynamic Video
# 1        Florida DJs May Face Felony for April Fools' W...
# 2             Technology ventures: From Idea to Enterprise
# 3        Note by Note: The Making of Steinway L1037 (2007)
# 4        Title II kills investment? Comcast and other I...
# 5                           Nuts and Bolts Business Advice
# 6              Ask HN: How to improve my personal website?
# 7        Shims, Jigs and Other Woodworking Concepts to ...
# 8                                   That self-appendectomy
# 9        Crate raises $4M seed round for its next-gen S...
# 10       Advertising Cannot Maintain the Internet. Here...
# 11                                          Coding Is Over
# 12       Show HN: Wio Link  ESP8266 Based Web of Things...
# 13                  Custom Deleters for C++ Smart Pointers
# 14              How often to update third party libraries?
# 15                        Review my AI based marketing bot
# 16       Ask HN: Am I the only one outraged by Twitter ...
# 17          Ten years later, did Boston's Big Dig deliver?
# 18               Valid.ly  Never send another OOPS message
# 19                     APOD: LIGO detects gravity waves...
# 20       Typeplate: a typographic starter kit encouragi...
# 21       Ask HN: Aby recent changes to CSS that broke m...
# 22       Streamroot makes video streaming cheaper thank...
# 23       VMware Confirms Layoffs as It Prepares for Del...
# 24       Firmware exploit can defeat new Windows securi...
# 25                The Sad State of Personal Knowledgebases
# 26                                US Robotics Network Taps
# 27                     Fundraising Advice for YC Companies
# 28       PSA: Intel WICS broken for years with official...
# 29         Ask HN: Looking for Employee #3 How do I do it?
#                                ...
# 20069    Show HN: Parse recipe ingredients using JavaSc...
# 20070    Engineering PhD student who died last year wil...
# 20071    Apples Amazing New Music App Hits All the Righ...
# 20072    Airbnb acquires team of Bitcoin and blockchain...
# 20073                                     Is Tesla Doomed?
# 20074    An Experiment with GitHub Pages, Jekyll and Tr...
# 20075    Tips from a Pro: An Introduction to Microscopi...
# 20076    Comcast CEO to angry customers: Its not me, it...
# 20077    The Renewed Case for the Reduced Instruction S...
# 20078    U.S. Judge Rejects Ubers Proposed $100M Settle...
# 20079                          English Syntax Highlighting
# 20080                   The Geek Behind Google's Map Quest
# 20081                 Usenet, what have you become? (2012)
# 20082    Colma, Calif., Is a Town of 2.2 Square Miles, ...
# 20083    The bizarre world of Bitcoin mining finds a ne...
# 20084    Microservice on-top of distributed filesystem ...
# 20085    Satoshi Nakamoto officially nominated for the ...
# 20086      Debian XScreenSaver package maintainer responds
# 20087          TSA Sued Over New Policy to Refuse Opt-Outs
# 20088    I have $10,000 dollars in my bank account. Am ...
# 20089    Users Really Do Plug in USB Drives They Find [...
# 20090    Visual Studio now available in cloud subscript...
# 20091    Thought leader gives talk that will inspire yo...
# 20092              On Botnets and Streaming Music Services
# 20093               Two new steps toward quantum computing
# 20094    How Purism Avoids Intels Active Management Tec...
# 20095            YC Application Translated and Broken Down
# 20096    Microkernels are slow and Elvis didn't do no d...
# 20097                        How Product Hunt really works
# 20098    RoboBrowser: Your friendly neighborhood web sc...
# Name: title, Length: 20099, dtype: object

# %%
test_urls = pd.Series([
 'https://www.amazon.com/Technology-Ventures-Enterprise-Thomas-Byers/dp/0073523429',
 'http://www.interactivedynamicvideo.com/',
 'http://www.nytimes.com/2007/11/07/movies/07stein.html?_r=0',
 'http://evonomics.com/advertising-cannot-maintain-internet-heres-solution/',
 'HTTPS://github.com/keppel/pinn',
 'Http://phys.org/news/2015-09-scale-solar-youve.html',
 'https://iot.seeed.cc',
 'http://www.bfilipek.com/2016/04/custom-deleters-for-c-smart-pointers.html',
 'http://beta.crowdfireapp.com/?beta=agnipath',
 'https://www.valid.ly'
])

# %%
#Extract domain path
pattern = r"https?://([\w\.]+)"  #r"\/\/([\w]+?[\.]?\w+\.\w+[\.]?[\w]+)\/?"

test_url_clean = test_urls.str.extract(pattern,expand=False)

test_url_clean
# Out:
# 0                     www.amazon.com
# 1    www.interactivedynamicvideo.com
# 2                    www.nytimes.com
# 3                      evonomics.com
# 4                         github.com
# 5                           phys.org
# 6                       iot.seeed.cc
# 7                   www.bfilipek.com
# 8              beta.crowdfireapp.com
# 9                       www.valid.ly
# dtype: object

# %%
domains = hn['url'].str.extract(pattern,expand=False)

domains.value_counts()
# Out:
# github.com                       1008
# medium.com                        825
# www.nytimes.com                   525
# www.theguardian.com               248
# techcrunch.com                    245
# www.youtube.com                   213
# www.bloomberg.com                 193
# arstechnica.com                   191
# www.washingtonpost.com            190
# www.wsj.com                       138
# www.theatlantic.com               137
# www.bbc.com                       134
# www.wired.com                     114
# www.theverge.com                  112
# www.bbc.co                        108
# en.wikipedia.org                  100
# twitter.com                        93
# qz.com                             85
# motherboard.vice.com               82
# www.newyorker.com                  81
# www.forbes.com                     78
# www.businessinsider.com            78
# nautil.us                          77
# www.nature.com                     72
# www.reuters.com                    71
# www.economist.com                  66
# arxiv.org                          62
# www.eff.org                        56
# venturebeat.com                    53
# www.vox.com                        51
#                                  ...
# cloudwith.me                        1
# samidavies.wordpress.com            1
# www.thesaturdaypaper.com            1
# news.cnrs.fr                        1
# sciencedomain.org                   1
# blog.mapillary.com                  1
# blog.csta.acm                       1
# www.hq.nasa                         1
# developer.clarifai.com              1
# bugs.mysql.com                      1
# www.innovatorsinresidence.com       1
# vorlonjs.com                        1
# blog.adbrain.com                    1
# arewegameyet.com                    1
# www.americanprogress.org            1
# nownownow.com                       1
# permalink.gmane.org                 1
# casualjavascript.com                1
# mthompson.org                       1
# www.embeddedrelated.com             1
# forumserver.twoplustwo.com          1
# www.willmcgugan.com                 1
# www.pidramble.com                   1
# annevankesteren.nl                  1
# fouroneone.io                       1
# familyinsafe.com                    1
# mkremins.github.io                  1
# www.getwox.com                      1
# wehaveyourdata.com                  1
# www.petemccormack.com               1
# Name: url, Length: 7023, dtype: int64

# %%
#Extract URL to 3 parts
pattern = r"(.+)://([\w\.]+)/?(.*)"

test_url_parts = test_urls.str.extract(pattern)
test_url_parts
# Out:
#        0                                1  \
# 0  https                   www.amazon.com
# 1   http  www.interactivedynamicvideo.com
# 2   http                  www.nytimes.com
# 3   http                    evonomics.com
# 4  HTTPS                       github.com
# 5   Http                         phys.org
# 6  https                     iot.seeed.cc
# 7   http                 www.bfilipek.com
# 8   http            beta.crowdfireapp.com
# 9  https                     www.valid.ly
#
#                                                    2
# 0  Technology-Ventures-Enterprise-Thomas-Byers/dp...
# 1
# 2                2007/11/07/movies/07stein.html?_r=0
# 3  advertising-cannot-maintain-internet-heres-sol...
# 4                                        keppel/pinn
# 5                news/2015-09-scale-solar-youve.html
# 6
# 7  2016/04/custom-deleters-for-c-smart-pointers.html
# 8                                     ?beta=agnipath
# 9

# %%
url_paths = hn['url'].str.extract(pattern)

url_paths
# Out:
#            0                                1  \
# 0       http  www.interactivedynamicvideo.com
# 1       http                  www.thewire.com
# 2      https                   www.amazon.com
# 3       http                  www.nytimes.com
# 4       http                  arstechnica.com
# 5        NaN                              NaN
# 6        NaN                              NaN
# 7       http                   firstround.com
# 8       http         www.southpolestation.com
# 9       http                   techcrunch.com
# 10      http                    evonomics.com
# 11     https                       medium.com
# 12     https                     iot.seeed.cc
# 13      http                 www.bfilipek.com
# 14       NaN                              NaN
# 15      http            beta.crowdfireapp.com
# 16       NaN                              NaN
# 17     https              www.bostonglobe.com
# 18     https                     www.valid.ly
# 19      http                    apod.nasa.gov
# 20      http                    typeplate.com
# 21       NaN                              NaN
# 22      http                   techcrunch.com
# 23      http                   techcrunch.com
# 24      http                  www.pcworld.com
# 25      http              marcusvorwaller.com
# 26      http                      www.usr.com
# 27     https             blog.ycombinator.com
# 28     https            communities.intel.com
# 29       NaN                              NaN
# ...      ...                              ...
# 20069  https                       github.com
# 20070   http                 host.madison.com
# 20071  https                    www.yahoo.com
# 20072   http                           qz.com
# 20073   http             www.roadandtrack.com
# 20074   http                         darek.dk
# 20075   http                 www.popphoto.com
# 20076   http                      www.vox.com
# 20077   http            www.eecs.berkeley.edu
# 20078   http                      www.wsj.com
# 20079   http               evanhahn.github.io
# 20080   http              www.fastcompany.com
# 20081   http    www.90percentofeverything.com
# 20082   http                  www.nytimes.com
# 20083  https           www.washingtonpost.com
# 20084  https                       medium.com
# 20085   http           www.huffingtonpost.com
# 20086  https                  bugs.debian.org
# 20087   http                     professional
# 20088  https                       medium.com
# 20089  https                       zakird.com
# 20090  https             www.visualstudio.com
# 20091  https                  www.youtube.com
# 20092   http             motherboard.vice.com
# 20093   http                         phys.org
# 20094  https                          puri.sm
# 20095  https                       medium.com
# 20096   http               blog.darknedgy.net
# 20097  https                       medium.com
# 20098  https                       github.com
#
#                                                        2
# 0
# 1      entertainment/2013/04/florida-djs-april-fools-...
# 2      Technology-Ventures-Enterprise-Thomas-Byers/dp...
# 3                    2007/11/07/movies/07stein.html?_r=0
# 4      business/2015/10/comcast-and-other-isps-boost-...
# 5                                                    NaN
# 6                                                    NaN
# 7      review/shims-jigs-and-other-woodworking-concep...
# 8                              trivia/igy1/appendix.html
# 9      2016/03/15/crate-raises-4m-seed-round-for-its-...
# 10     advertising-cannot-maintain-internet-heres-sol...
# 11                  @loorinm/coding-is-over-6d653abe8da8
# 12
# 13     2016/04/custom-deleters-for-c-smart-pointers.html
# 14                                                   NaN
# 15                                        ?beta=agnipath
# 16                                                   NaN
# 17     magazine/2015/12/29/years-later-did-big-dig-de...
# 18
# 19                                    apod/astropix.html
# 20
# 21                                                   NaN
# 22     2015/12/10/streamroot-makes-video-streaming-ch...
# 23     2016/01/26/vmware-confirms-layoffs-in-earnings...
# 24     article/3091104/firmware-exploit-can-defeat-ne...
# 25              blog/2015/12/14/personal-knowledgebases/
# 26                          en/products/networking-taps/
# 27                   fundraising-advice-for-yc-companies
# 28                                          thread/96038
# 29                                                   NaN
# ...                                                  ...
# 20069                          herkyl/ingredients-parser
# 20070  wsj/news/local/uw-engineering-phd-student-who-...
# 20071  tech/apple-s-amazing-new-music-134702380626744...
# 20072  657246/airbnb-just-acquired-a-team-of-bitcoin-...
# 20073                 car-culture/a26859/bob-lutz-tesla/
# 20074  2016/05/29/an-experiment-with-github-pages-jek...
# 20075                   tips-pro-microscopic-photography
# 20076  business-and-finance/2015/12/15/10161100/brian...
# 20077              Pubs/TechRpts/2016/EECS-2016-130.html
# 20078  articles/u-s-judge-rejects-ubers-proposed-100-...
# 20079                         English-text-highlighting/
# 20080  3060811/most-creative-people/the-geek-behind-g...
# 20081            2012/08/28/usenet-what-have-you-become/
# 20082                      2006/12/09/us/09cemetery.html
# 20083  world/asia_pacific/in-chinas-tibetan-highlands...
# 20084  @lorenzogotuned/applying-some-good-open-source...
# 20085  bhagwan-chowdry/i-shall-happily-accept-th_b_84...
# 20086               cgi-bin/bugreport.cgi?bug=819703#425
# 20087  -troublemaker.com/2015/12/24/corbett-sues-tsa-...
# 20088  @sktgthill/i-have-10-000-dollars-in-my-bank-ac...
# 20089                                     papers/usb.pdf
# 20090                             products/how-to-buy-vs
# 20091                                watch?v=_ZBKX-6Gz6A
# 20092  read/i-built-a-botnet-that-could-destroy-spoti...
# 20093                      news/2015-11-big-quantum.html
# 20094  philosophy/how-purism-avoids-intels-active-man...
# 20095  @zreitano/the-yc-application-broken-down-and-t...
# 20096                           technology/2016/01/01/0/
# 20097  @benjiwheeler/how-product-hunt-really-works-d8...
# 20098                                 jmcarp/robobrowser
#
# [20099 rows x 3 columns]

# %%
# use ?P<name> to give column names for each part
pattern = r"(?P<protocol>.+)://(?P<domain>[\w\.]+)/?(?P<path>.*)"

url_parts = hn['url'].str.extract(pattern)

url_parts
# Out:
#       protocol                           domain  \
# 0         http  www.interactivedynamicvideo.com
# 1         http                  www.thewire.com
# 2        https                   www.amazon.com
# 3         http                  www.nytimes.com
# 4         http                  arstechnica.com
# 5          NaN                              NaN
# 6          NaN                              NaN
# 7         http                   firstround.com
# 8         http         www.southpolestation.com
# 9         http                   techcrunch.com
# 10        http                    evonomics.com
# 11       https                       medium.com
# 12       https                     iot.seeed.cc
# 13        http                 www.bfilipek.com
# 14         NaN                              NaN
# 15        http            beta.crowdfireapp.com
# 16         NaN                              NaN
# 17       https              www.bostonglobe.com
# 18       https                     www.valid.ly
# 19        http                    apod.nasa.gov
# 20        http                    typeplate.com
# 21         NaN                              NaN
# 22        http                   techcrunch.com
# 23        http                   techcrunch.com
# 24        http                  www.pcworld.com
# 25        http              marcusvorwaller.com
# 26        http                      www.usr.com
# 27       https             blog.ycombinator.com
# 28       https            communities.intel.com
# 29         NaN                              NaN
# ...        ...                              ...
# 20069    https                       github.com
# 20070     http                 host.madison.com
# 20071    https                    www.yahoo.com
# 20072     http                           qz.com
# 20073     http             www.roadandtrack.com
# 20074     http                         darek.dk
# 20075     http                 www.popphoto.com
# 20076     http                      www.vox.com
# 20077     http            www.eecs.berkeley.edu
# 20078     http                      www.wsj.com
# 20079     http               evanhahn.github.io
# 20080     http              www.fastcompany.com
# 20081     http    www.90percentofeverything.com
# 20082     http                  www.nytimes.com
# 20083    https           www.washingtonpost.com
# 20084    https                       medium.com
# 20085     http           www.huffingtonpost.com
# 20086    https                  bugs.debian.org
# 20087     http                     professional
# 20088    https                       medium.com
# 20089    https                       zakird.com
# 20090    https             www.visualstudio.com
# 20091    https                  www.youtube.com
# 20092     http             motherboard.vice.com
# 20093     http                         phys.org
# 20094    https                          puri.sm
# 20095    https                       medium.com
# 20096     http               blog.darknedgy.net
# 20097    https                       medium.com
# 20098    https                       github.com
#
#                                                     path
# 0
# 1      entertainment/2013/04/florida-djs-april-fools-...
# 2      Technology-Ventures-Enterprise-Thomas-Byers/dp...
# 3                    2007/11/07/movies/07stein.html?_r=0
# 4      business/2015/10/comcast-and-other-isps-boost-...
# 5                                                    NaN
# 6                                                    NaN
# 7      review/shims-jigs-and-other-woodworking-concep...
# 8                              trivia/igy1/appendix.html
# 9      2016/03/15/crate-raises-4m-seed-round-for-its-...
# 10     advertising-cannot-maintain-internet-heres-sol...
# 11                  @loorinm/coding-is-over-6d653abe8da8
# 12
# 13     2016/04/custom-deleters-for-c-smart-pointers.html
# 14                                                   NaN
# 15                                        ?beta=agnipath
# 16                                                   NaN
# 17     magazine/2015/12/29/years-later-did-big-dig-de...
# 18
# 19                                    apod/astropix.html
# 20
# 21                                                   NaN
# 22     2015/12/10/streamroot-makes-video-streaming-ch...
# 23     2016/01/26/vmware-confirms-layoffs-in-earnings...
# 24     article/3091104/firmware-exploit-can-defeat-ne...
# 25              blog/2015/12/14/personal-knowledgebases/
# 26                          en/products/networking-taps/
# 27                   fundraising-advice-for-yc-companies
# 28                                          thread/96038
# 29                                                   NaN
# ...                                                  ...
# 20069                          herkyl/ingredients-parser
# 20070  wsj/news/local/uw-engineering-phd-student-who-...
# 20071  tech/apple-s-amazing-new-music-134702380626744...
# 20072  657246/airbnb-just-acquired-a-team-of-bitcoin-...
# 20073                 car-culture/a26859/bob-lutz-tesla/
# 20074  2016/05/29/an-experiment-with-github-pages-jek...
# 20075                   tips-pro-microscopic-photography
# 20076  business-and-finance/2015/12/15/10161100/brian...
# 20077              Pubs/TechRpts/2016/EECS-2016-130.html
# 20078  articles/u-s-judge-rejects-ubers-proposed-100-...
# 20079                         English-text-highlighting/
# 20080  3060811/most-creative-people/the-geek-behind-g...
# 20081            2012/08/28/usenet-what-have-you-become/
# 20082                      2006/12/09/us/09cemetery.html
# 20083  world/asia_pacific/in-chinas-tibetan-highlands...
# 20084  @lorenzogotuned/applying-some-good-open-source...
# 20085  bhagwan-chowdry/i-shall-happily-accept-th_b_84...
# 20086               cgi-bin/bugreport.cgi?bug=819703#425
# 20087  -troublemaker.com/2015/12/24/corbett-sues-tsa-...
# 20088  @sktgthill/i-have-10-000-dollars-in-my-bank-ac...
# 20089                                     papers/usb.pdf
# 20090                             products/how-to-buy-vs
# 20091                                watch?v=_ZBKX-6Gz6A
# 20092  read/i-built-a-botnet-that-could-destroy-spoti...
# 20093                      news/2015-11-big-quantum.html
# 20094  philosophy/how-purism-avoids-intels-active-man...
# 20095  @zreitano/the-yc-application-broken-down-and-t...
# 20096                           technology/2016/01/01/0/
# 20097  @benjiwheeler/how-product-hunt-really-works-d8...
# 20098                                 jmcarp/robobrowser
#
# [20099 rows x 3 columns]
